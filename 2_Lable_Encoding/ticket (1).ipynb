# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/home/infinitex/Desktop/JupiterNotebook/Assignment2/full.csv")

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#top 5
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
#last 5
df.tail(5)
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# 1304   NaN      0      0           A.5. 3236    8.0500  ...        S  1227.0
# 1305  39.0      0      0            PC 17758  108.9000  ...        C   229.0
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500  ...        S  1169.0
# 1307   NaN      0      0              359309    8.0500  ...        S  1289.0
# 1308   NaN      1      1                2668   22.3583  ...        C   702.0
#
#                                  Name_wiki Age_wiki  \
# ...

# %%
#last records
df.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# 1304   NaN      0      0           A.5. 3236    8.0500  ...        S  1227.0
# 1305  39.0      0      0            PC 17758  108.9000  ...        C   229.0
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500  ...        S  1169.0
# 1307   NaN      0      0              359309    8.0500  ...        S  1289.0
# 1308   NaN      1      1                2668   22.3583  ...        C   702.0
#
#                                  Name_wiki Age_wiki  \
# ...

# %%
#size
size = df.size
size
# Out:
# 27489

# %%
#rows, colums
df.shape
# Out:
# (1309, 21)

# %%
#dimentions 2D, 3D
df.ndim
# Out:
# 2

# %%
df.info
# Out:
# <bound method DataFrame.info of       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#concise summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %% [markdown]
# > LABLE ENCODING

# %%
df.shape
# Out:
# (1309, 21)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
df['Boarded'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', 'Belfast', nan],
#       dtype=object)

# %%
#import label encoder
#drawback take 1, 2, 3 index prioritywise
from sklearn import preprocessing

# %%
#encode labels in column Boarded i.e convert categorical into numercial data
df['Boarded'] = label_encoder.fit_transform(df['Boarded'])

# %%
# label_encoder object knows 
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# %%
df['Boarded'].unique()
# Out:
# array([3, 1, 2, 0, 4])

# %% [markdown]
# > ONE HOT ENCODING

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'].value_counts()
#drawback for every unique value in the column, new columns are create, increasing size
# Out:
# Sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
#transform
one_hot_encoded_data = pd.get_dummies(df, columns = ['Sex'])

# %%
df.get(["Sex"])
# Out:
#          Sex
# 0       male
# 1     female
# 2     female
# 3     female
# 4       male
# ...      ...
# 1304    male
# 1305  female
# 1306    male
# 1307    male
# 1308    male
#
# [1309 rows x 1 columns]

# %%
print(one_hot_encoded_data)
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name   Age  SibSp  Parch  \
# 0                               Braund, Mr. Owen Harris  22.0      1      0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                                Heikkinen, Miss. Laina  26.0      0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                              Allen, Mr. William Henry  35.0      0      0
# ...

# %%
#list names of all columns, find new columns created too
print(one_hot_encoded_data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class', 'Sex_female', 'Sex_male'],
#       dtype='object')

# %%
#print new created column
print(one_hot_encoded_data['Sex_female'])
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: Sex_female, Length: 1309, dtype: bool
