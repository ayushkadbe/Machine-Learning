# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #importing the wine csv file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
wine = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Wine.csv")
wine
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %% [markdown]
# #Display correlation matrix. Identify corelated attributes.

# %%
correlation_matrix = wine.corr()
correlation_matrix
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094397  0.211545     -0.310235   0.270798
# Malic_Acid            0.094397    1.000000  0.164045      0.288500  -0.054575
# Ash                   0.211545    0.164045  1.000000      0.443367   0.286587
# Ash_Alcanity         -0.310235    0.288500  0.443367      1.000000  -0.083333
# Magnesium             0.270798   -0.054575  0.286587     -0.083333   1.000000
# Total_Phenols         0.289101   -0.335167  0.128980     -0.321113   0.214401
# Flavanoids            0.236815   -0.411007  0.115077     -0.351370   0.195784
# Nonflavanoid_Phenols -0.155929    0.292977  0.186230      0.361922  -0.256294
# Proanthocyanins       0.136698   -0.220746  0.009652     -0.197327   0.236441
# Color_Intensity       0.546364    0.248985  0.258887      0.018732   0.199950
# Hue                  -0.071747   -0.561296 -0.074667     -0.273955   0.055398
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %% [markdown]
# #3. Build simple linear regression

# %%
X = wine.iloc[:,6:7].values
Y =wine.iloc[:,8:9].values
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test =train_test_split(X,Y, test_size=0.33,random_state=0)
X_train, X_test, Y_train, Y_test
# Out:
# (array([[0.6 ],
#         [0.83],
#         [2.19],
#         [1.59],
#         [0.58],
#         [2.5 ],
#         [1.25],
#         [0.7 ],
#         [1.79],
#         [3.24],
#         [0.57],
#         [2.27],
#         [0.99],
#         [2.63],
#         [3.32],
#         [2.92],
#         [2.89],
#         [0.51],
#         [1.1 ],
#         [2.58],
#         [2.65],
#         [1.6 ],
#         [0.92],
#         [0.49],
#         [3.27],
#         [0.63],
#         [1.59],
#         [1.75],
#         [2.13],
#         [3.03],
#         [1.28],
#         [3.54],
#         [2.92],
#         [1.94],
#         [3.69],
#         [0.47],
#         [2.37],
#         [0.47],
#         [3.17],
#         [2.91],
#         [1.85],
#         [3.74],
#         [2.17],
#         [2.03],
#         [3.49],
#         [0.68],
#         [1.76],
#         [2.52],
#         [1.3 ],
#         [1.57],
#         [2.21],
#         [1.25],
#         [2.76],
#         [0.6 ],
#         [1.28],
# ...

# %%
from sklearn.linear_model import LinearRegression
slrmodel = LinearRegression()
slrmodel.fit(X_train,Y_train)
Y_pred = slrmodel.predict(X_test)
Y_pred
# Out:
# array([[1.99260947],
#        [1.35558298],
#        [2.07534019],
#        [1.94297104],
#        [1.88919608],
#        [2.89437425],
#        [1.83128458],
#        [1.17357541],
#        [1.63273087],
#        [1.41349448],
#        [0.99984091],
#        [0.93365634],
#        [2.19529972],
#        [2.34421501],
#        [1.14048312],
#        [1.72787119],
#        [1.9264249 ],
#        [2.41867265],
#        [1.37626565],
#        [2.02983829],
#        [2.10843247],
#        [1.7981923 ],
#        [1.90574222],
#        [1.58722897],
#        [1.24389651],
#        [1.73200772],
#        [2.09602286],
#        [1.49208865],
#        [1.63273087],
#        [1.07429855],
#        [2.00915562],
#        [2.03397483],
#        [1.51690787],
#        [1.88919608],
#        [2.02570176],
#        [2.03397483],
#        [1.02466012],
#        [1.39694833],
#        [1.72787119],
#        [1.1032543 ],
#        [1.87264994],
#        [2.13738822],
#        [1.72373465],
# ...

# %%
print(slrmodel.intercept_)
print(slrmodel.coef_)
# Out:
# [0.79301412]
# [[0.41365357]]

# %%
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train, slrmodel.predict(X_train),color='blue')
plt.xlabel('Flavanoids')
plt.ylabel('Proanthocyanins')
plt.show()

# %% [markdown]
# #**4.Build multiple linear regression**

# %%
from sklearn.metrics import mean_squared_error, r2_score
X = wine[['Total_Phenols','Proanthocyanins','OD280']]
Y = wine[['Flavanoids']]
X,Y
# Out:
# (     Total_Phenols  Proanthocyanins  OD280
#  0             2.80             2.29   3.92
#  1             2.65             1.28   3.40
#  2             2.80             2.81   3.17
#  3             3.85             2.18   3.45
#  4             2.80             1.82   2.93
#  ..             ...              ...    ...
#  173           1.68             1.06   1.74
#  174           1.80             1.41   1.56
#  175           1.59             1.35   1.56
#  176           1.65             1.46   1.62
#  177           2.05             1.35   1.60
#
#  [178 rows x 3 columns],
#       Flavanoids
#  0          3.06
#  1          2.76
#  2          3.24
#  3          3.49
#  4          2.69
#  ..          ...
#  173        0.61
#  174        0.75
#  175        0.69
#  176        0.68
#  177        0.76
#
#  [178 rows x 1 columns])

# %% [markdown]
# #Splitting train and test dataset

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train, X_test, Y_train, Y_test
# Out:
# (     Total_Phenols  Proanthocyanins  OD280
#  158           2.80             2.70   1.96
#  137           1.79             1.10   1.69
#  98            3.52             1.95   2.77
#  159           2.60             2.29   1.78
#  38            2.40             1.37   2.69
#  ..             ...              ...    ...
#  71            2.95             1.87   3.16
#  106           1.65             1.63   3.17
#  14            3.30             2.96   3.00
#  92            1.38             1.62   2.06
#  102           2.56             1.31   3.38
#
#  [142 rows x 3 columns],
#       Total_Phenols  Proanthocyanins  OD280
#  19            2.70             1.66   3.36
#  45            2.85             1.25   3.33
#  140           1.54             0.75   2.31
#  30            3.00             2.38   2.71
#  67            2.11             1.04   3.48
#  16            2.80             1.97   2.65
#  119           2.00             1.87   3.05
#  174           1.80             1.41   1.56
# ...

# %% [markdown]
# #building model and training model

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Predication and evalute the model

# %%
Y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Mean Squared Error: 0.1517832901789916
# R-squared: 0.8388143504033444
# Coefficients: [[0.78797217 0.23475162 0.53213411]]
# Intercept: [-1.55883574]

# %%
plt.scatter(Y_test, Y_pred)
plt.xlabel("'Total_Phenols','Proanthocyanins','OD280'")
plt.ylabel("'Flavanoids'")
plt.title("Multiple linear regression")
plt.show()

# %% [markdown]
# #**5.Build polynomial regression model**

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly_reg = PolynomialFeatures(degree=4)#more the degre more the curve
X_poly = poly_reg.fit_transform(X_test)
lin_reg = LinearRegression()
lin_reg.fit(X_poly,Y_test)

X_range = np.arange(0.1,3,0.01)

X_range_poly = poly_reg.transform(X_range.reshape(-1,1))

Y_pred = lin_reg.predict(X_range_poly)

plt.scatter(X_test,Y_test, color='red')
plt.plot(X_range,Y_pred,color='blue',label='Polynomial Regression Curve')
plt.title('Polynomial Regression')
plt.xlabel('Total_phenols, Proanthocyanins, OD280')
plt.ylabel('Flavanoids')
plt.legend()
plt.show()

# %% [markdown]
# #**6.Build ridge regression model**

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
X = wine.iloc[:, 5:6].values
Y= wine.iloc[:,11].values
X,Y
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=0)
X_train, X_test, Y_train, Y_test
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train, y_train)
    print(f"Alpha = {alpha}, Coefficients = {ridge.coef_},MSE = {mse}")
# Out:
# Alpha = 0.1, Coefficients = [0.82188286],MSE = 0.1517832901789916
# Alpha = 1.0, Coefficients = [0.80357108],MSE = 0.1517832901789916
# Alpha = 10.0, Coefficients = [0.65715506],MSE = 0.1517832901789916

# %% [markdown]
# #**Build Lasso regression model**

# %%
from sklearn.linear_model import Lasso
alphas = [0.1, 1.0, 10.0]  # Different values of alpha

for alpha in alphas:
    lasso = Lasso(alpha=alpha)
    lasso.fit(X_train, Y_train)
    Y_pred = lasso.predict(X_test)
    mse = mean_squared_error(Y_test, Y_pred)
    print(f"Alpha = {alpha}, MSE = {mse}")

    #Observe the coefficients for each alpha
    print(f"Coefficients for Alpha = {alpha}: {lasso.coef_}")
# Out:
# Alpha = 0.1, MSE = 0.26048572437716166
# Coefficients for Alpha = 0.1: [0.55489576]
# Alpha = 1.0, MSE = 0.48042543412048566
# Coefficients for Alpha = 1.0: [0.]
# Alpha = 10.0, MSE = 0.48042543412048566
# Coefficients for Alpha = 10.0: [0.]
